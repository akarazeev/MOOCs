# %% [markdown]
# # CartPole-v0, Q-Learning

# %% [markdown]
# https://medium.com/@tuzzer/cart-pole-balancing-with-q-learning-b54c6068d947#.2t2lx4s9a

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from scipy import stats as ss
# %matplotlib inline

# %%
#
# Observation dimensionality - 4: (x, x', theta, theta')
# Action space is discrete
# State space  is continuous
#

env = gym.make('CartPole-v0')
eps = 0.3

NUM_BUCKETS = (1, 1, 6, 3)  # (x, x', theta, theta')
NUM_ACTIONS = env.action_space.n  # 0 or 1
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

import math
STATE_BOUNDS[1] = (-0.5, 0.5)
STATE_BOUNDS[3] = (-math.radians(50), math.radians(50))
ACTION_INDEX = len(NUM_BUCKETS)

q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,))

MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1

NUM_EPISODES = 1000
MAX_T = 250
STREAK_TO_END = 120
SOLVED_T = 199
DEBUG_MODE = False

import random

def select_action(state, eps):
    action = None
    if random.random() < eps:
        action = env.action_space.sample()
    else:
        action = np.argmax(q_table[state])
    return action


def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25)))


def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25)))


def state_to_bucket(state):
    bucket_indice = []
    bucket_index = None
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            scaling = (NUM_BUCKETS[i] - 1) / bound_width
            offset = scaling * STATE_BOUNDS[i][0]
            bucket_index = int(round(state[i] * scaling - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)


def run():    
    discount_factor = 0.99
    num_streaks = 0
    
    for episode in range(NUM_EPISODES):
        exploration_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)
        
        obv = env.reset()
        state_0 = state_to_bucket(obv)
        for t in range(MAX_T):
            env.render()
            action = select_action(state_0, exploration_rate)
            obv, reward, done, _ = env.step(action)
            state = state_to_bucket(obv)
            best_q = np.amax(q_table[state])  # get max along the axis _state_
            
            q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor*best_q\
                                                             - q_table[state_0 + (action,)])
            state_0 = state
            
            if DEBUG_MODE:
                print("\nEpisode: {}".format(episode))
                print("t: {}".format(t))
                print("Action: {}".format(action))
                print("State: {}".format(state))
                print("Reward: {}".format(reward))
                print("Best Q: {}".format(best_q))
                print("Exploration rate: {}".format(exploration_rate))
                print("Learning rate: {}".format(learning_rate))
                print("Streaks: {}".format(num_streaks))
                print("<<<----|--------|---->>>")
                
            if done:
                print("Episode {} finished after {} timesteps".format(episode, t))
                if t >= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break
                
        if num_streaks > STREAK_TO_END:
            break
# Out:
# [2017-03-01 16:20:01,716] Making new env: CartPole-v0

# %%
run()
env.close()
# Out:
# Episode 0 finished after 13 timesteps
# Episode 1 finished after 9 timesteps
# Episode 2 finished after 15 timesteps
# Episode 3 finished after 16 timesteps
# Episode 4 finished after 15 timesteps
# Episode 5 finished after 30 timesteps
# Episode 6 finished after 13 timesteps
# Episode 7 finished after 12 timesteps
# Episode 8 finished after 24 timesteps
# Episode 9 finished after 43 timesteps
# Episode 10 finished after 19 timesteps
# Episode 11 finished after 52 timesteps
# Episode 12 finished after 12 timesteps
# Episode 13 finished after 31 timesteps
# Episode 14 finished after 13 timesteps
# Episode 15 finished after 11 timesteps
# Episode 16 finished after 16 timesteps
# Episode 17 finished after 26 timesteps
# Episode 18 finished after 9 timesteps
# Episode 19 finished after 19 timesteps
# Episode 20 finished after 20 timesteps
# Episode 21 finished after 28 timesteps
# Episode 22 finished after 14 timesteps
# Episode 23 finished after 73 timesteps
# Episode 24 finished after 15 timesteps
# Episode 25 finished after 29 timesteps
# Episode 26 finished after 14 timesteps
# Episode 27 finished after 47 timesteps
# Episode 28 finished after 11 timesteps
# Episode 29 finished after 50 timesteps
# Episode 30 finished after 87 timesteps
# Episode 31 finished after 17 timesteps
# Episode 32 finished after 13 timesteps
# Episode 33 finished after 21 timesteps
# Episode 34 finished after 9 timesteps
# Episode 35 finished after 11 timesteps
# Episode 36 finished after 45 timesteps
# Episode 37 finished after 18 timesteps
# Episode 38 finished after 11 timesteps
# Episode 39 finished after 18 timesteps
# Episode 40 finished after 23 timesteps
# Episode 41 finished after 28 timesteps
# Episode 42 finished after 15 timesteps
# Episode 43 finished after 18 timesteps
# Episode 44 finished after 18 timesteps
# Episode 45 finished after 30 timesteps
# Episode 46 finished after 11 timesteps
# Episode 47 finished after 31 timesteps
# Episode 48 finished after 41 timesteps
# Episode 49 finished after 8 timesteps
# Episode 50 finished after 30 timesteps
# Episode 51 finished after 8 timesteps
# Episode 52 finished after 17 timesteps
# Episode 53 finished after 9 timesteps
# Episode 54 finished after 15 timesteps
# Episode 55 finished after 7 timesteps
# Episode 56 finished after 15 timesteps
# Episode 57 finished after 9 timesteps
# Episode 58 finished after 23 timesteps
# Episode 59 finished after 19 timesteps
# Episode 60 finished after 10 timesteps
# Episode 61 finished after 30 timesteps
# Episode 62 finished after 11 timesteps
# Episode 63 finished after 25 timesteps
# Episode 64 finished after 26 timesteps
# Episode 65 finished after 75 timesteps
# Episode 66 finished after 28 timesteps
# Episode 67 finished after 12 timesteps
# Episode 68 finished after 20 timesteps
# Episode 69 finished after 10 timesteps
# Episode 70 finished after 18 timesteps
# Episode 71 finished after 11 timesteps
# Episode 72 finished after 13 timesteps
# Episode 73 finished after 17 timesteps
# Episode 74 finished after 84 timesteps
# Episode 75 finished after 61 timesteps
# Episode 76 finished after 11 timesteps
# Episode 77 finished after 53 timesteps
# Episode 78 finished after 14 timesteps
# Episode 79 finished after 31 timesteps
# Episode 80 finished after 9 timesteps
# Episode 81 finished after 14 timesteps
# Episode 82 finished after 31 timesteps
# Episode 83 finished after 25 timesteps
# Episode 84 finished after 11 timesteps
# Episode 85 finished after 12 timesteps
# Episode 86 finished after 33 timesteps
# Episode 87 finished after 37 timesteps
# Episode 88 finished after 46 timesteps
# Episode 89 finished after 12 timesteps
# Episode 90 finished after 12 timesteps
# Episode 91 finished after 32 timesteps
# Episode 92 finished after 28 timesteps
# Episode 93 finished after 28 timesteps
# Episode 94 finished after 12 timesteps
# Episode 95 finished after 66 timesteps
# Episode 96 finished after 28 timesteps
# Episode 97 finished after 12 timesteps
# Episode 98 finished after 13 timesteps
# Episode 99 finished after 16 timesteps
# Episode 100 finished after 10 timesteps
# Episode 101 finished after 22 timesteps
# Episode 102 finished after 39 timesteps
# Episode 103 finished after 10 timesteps
# Episode 104 finished after 25 timesteps
# Episode 105 finished after 15 timesteps
# Episode 106 finished after 80 timesteps
# Episode 107 finished after 10 timesteps
# Episode 108 finished after 49 timesteps
# Episode 109 finished after 197 timesteps
# Episode 110 finished after 19 timesteps
# Episode 111 finished after 25 timesteps
# Episode 112 finished after 10 timesteps
# Episode 113 finished after 9 timesteps
# Episode 114 finished after 15 timesteps
# Episode 115 finished after 15 timesteps
# Episode 116 finished after 18 timesteps
# Episode 117 finished after 10 timesteps
# Episode 118 finished after 11 timesteps
# Episode 119 finished after 9 timesteps
# Episode 120 finished after 177 timesteps
# Episode 121 finished after 52 timesteps
# Episode 122 finished after 59 timesteps
# Episode 123 finished after 8 timesteps
# Episode 124 finished after 96 timesteps
# Episode 125 finished after 30 timesteps
# Episode 126 finished after 68 timesteps
# Episode 127 finished after 199 timesteps
# Episode 128 finished after 199 timesteps
# Episode 129 finished after 145 timesteps
# Episode 130 finished after 19 timesteps
# Episode 131 finished after 21 timesteps
# Episode 132 finished after 54 timesteps
# Episode 133 finished after 199 timesteps
# Episode 134 finished after 43 timesteps
# Episode 135 finished after 24 timesteps
# Episode 136 finished after 199 timesteps
# Episode 137 finished after 199 timesteps
# Episode 138 finished after 199 timesteps
# Episode 139 finished after 199 timesteps
# Episode 140 finished after 199 timesteps
# Episode 141 finished after 199 timesteps
# Episode 142 finished after 110 timesteps
# Episode 143 finished after 30 timesteps
# Episode 144 finished after 24 timesteps
# Episode 145 finished after 10 timesteps
# Episode 146 finished after 17 timesteps
# Episode 147 finished after 23 timesteps
# Episode 148 finished after 14 timesteps
# Episode 149 finished after 75 timesteps
# Episode 150 finished after 199 timesteps
# Episode 151 finished after 199 timesteps
# Episode 152 finished after 199 timesteps
# Episode 153 finished after 199 timesteps
# Episode 154 finished after 199 timesteps
# Episode 155 finished after 199 timesteps
# Episode 156 finished after 199 timesteps
# Episode 157 finished after 199 timesteps
# Episode 158 finished after 199 timesteps
# Episode 159 finished after 199 timesteps
# Episode 160 finished after 199 timesteps
# Episode 161 finished after 199 timesteps
# Episode 162 finished after 199 timesteps
# Episode 163 finished after 199 timesteps
# Episode 164 finished after 199 timesteps
# Episode 165 finished after 199 timesteps
# Episode 166 finished after 199 timesteps
# Episode 167 finished after 199 timesteps
# Episode 168 finished after 199 timesteps
# Episode 169 finished after 199 timesteps
# Episode 170 finished after 199 timesteps
# Episode 171 finished after 199 timesteps
# Episode 172 finished after 199 timesteps
# Episode 173 finished after 199 timesteps
# Episode 174 finished after 199 timesteps
# Episode 175 finished after 199 timesteps
# Episode 176 finished after 199 timesteps
# Episode 177 finished after 199 timesteps
# Episode 178 finished after 199 timesteps
# Episode 179 finished after 199 timesteps
# Episode 180 finished after 199 timesteps
# Episode 181 finished after 199 timesteps
# Episode 182 finished after 199 timesteps
# Episode 183 finished after 199 timesteps
# Episode 184 finished after 199 timesteps
# Episode 185 finished after 199 timesteps
# Episode 186 finished after 199 timesteps
# Episode 187 finished after 199 timesteps
# Episode 188 finished after 199 timesteps
# Episode 189 finished after 199 timesteps
# Episode 190 finished after 199 timesteps
# Episode 191 finished after 199 timesteps
# Episode 192 finished after 199 timesteps
# Episode 193 finished after 199 timesteps
# Episode 194 finished after 199 timesteps
# Episode 195 finished after 199 timesteps
# Episode 196 finished after 199 timesteps
# Episode 197 finished after 199 timesteps
# Episode 198 finished after 199 timesteps
# Episode 199 finished after 199 timesteps
# Episode 200 finished after 199 timesteps
# Episode 201 finished after 199 timesteps
# Episode 202 finished after 199 timesteps
# Episode 203 finished after 199 timesteps
# Episode 204 finished after 199 timesteps
# Episode 205 finished after 199 timesteps
# Episode 206 finished after 199 timesteps
# Episode 207 finished after 199 timesteps
# Episode 208 finished after 199 timesteps
# Episode 209 finished after 199 timesteps
# Episode 210 finished after 199 timesteps
# Episode 211 finished after 199 timesteps
# Episode 212 finished after 199 timesteps
# Episode 213 finished after 199 timesteps
# Episode 214 finished after 199 timesteps
# Episode 215 finished after 199 timesteps
# Episode 216 finished after 199 timesteps
# Episode 217 finished after 199 timesteps
# Episode 218 finished after 199 timesteps
# Episode 219 finished after 199 timesteps
# Episode 220 finished after 199 timesteps
# Episode 221 finished after 199 timesteps
# Episode 222 finished after 199 timesteps
# Episode 223 finished after 199 timesteps
# Episode 224 finished after 199 timesteps
# Episode 225 finished after 199 timesteps
# Episode 226 finished after 199 timesteps
# Episode 227 finished after 199 timesteps
# Episode 228 finished after 199 timesteps
# Episode 229 finished after 199 timesteps
# Episode 230 finished after 199 timesteps
# Episode 231 finished after 199 timesteps
# Episode 232 finished after 199 timesteps
# Episode 233 finished after 199 timesteps
# Episode 234 finished after 199 timesteps
# Episode 235 finished after 199 timesteps
# Episode 236 finished after 199 timesteps
# Episode 237 finished after 199 timesteps
# Episode 238 finished after 199 timesteps
# Episode 239 finished after 199 timesteps
# Episode 240 finished after 199 timesteps
# Episode 241 finished after 199 timesteps
# Episode 242 finished after 199 timesteps
# Episode 243 finished after 199 timesteps
# Episode 244 finished after 199 timesteps
# Episode 245 finished after 199 timesteps
# Episode 246 finished after 199 timesteps
# Episode 247 finished after 199 timesteps
# Episode 248 finished after 199 timesteps
# Episode 249 finished after 199 timesteps
# Episode 250 finished after 199 timesteps
# Episode 251 finished after 199 timesteps
# Episode 252 finished after 199 timesteps
# Episode 253 finished after 199 timesteps
# Episode 254 finished after 199 timesteps
# Episode 255 finished after 199 timesteps
# Episode 256 finished after 199 timesteps
# Episode 257 finished after 199 timesteps
# Episode 258 finished after 199 timesteps
# Episode 259 finished after 199 timesteps
# Episode 260 finished after 199 timesteps
# Episode 261 finished after 199 timesteps
# Episode 262 finished after 199 timesteps
# Episode 263 finished after 199 timesteps
# Episode 264 finished after 199 timesteps
# Episode 265 finished after 199 timesteps
# Episode 266 finished after 199 timesteps
# Episode 267 finished after 199 timesteps
# Episode 268 finished after 199 timesteps
# Episode 269 finished after 199 timesteps
# Episode 270 finished after 199 timesteps
